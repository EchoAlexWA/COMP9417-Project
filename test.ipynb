# %%
from model_pipeline import get_train_test, select_non_nan_rows, preprocess_data, data_formatted

# %%
import pandas as pd

# %%
train_dataset, test_dataset=get_train_test()
train_dataset_NMHC, test_dataset_NMHC=get_train_test(if_NMHC=True)

# %%
short_features = {'lags': [1,3,6,12,24], 'window_sizes': [3,6], 'anomaly_detection_enabled': False}
X_train, Y_train, X_test, Y_test=preprocess_data(train_dataset, test_dataset, 'CO(GT)', short_features)
# Out:
# C:\LocalFile\9417 Project\.venv\Lib\site-packages\sklearn\pipeline.py:61: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4650 entries, 2004-03-11 18:00:00 to 2004-12-27 00:00:00
# Data columns (total 70 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PT08.S1(CO)          4650 non-null   float64
#  1   PT08.S2(NMHC)        4650 non-null   float64
#  2   PT08.S3(NOx)         4650 non-null   float64
#  3   PT08.S4(NO2)         4650 non-null   float64
#  4   PT08.S5(O3)          4650 non-null   float64
#  5   T                    4650 non-null   float64
#  6   RH                   4650 non-null   float64
#  7   AH                   4650 non-null   float64
#  8   PT08.S1(CO)_lag1     4650 non-null   float64
#  9   PT08.S1(CO)_lag3     4650 non-null   float64
#  10  PT08.S1(CO)_lag6     4650 non-null   float64
#  11  PT08.S1(CO)_lag12    4650 non-null   float64
#  12  PT08.S1(CO)_lag24    4650 non-null   float64
#  13  PT08.S2(NMHC)_lag1   4650 non-null   float64
# ...

# %%
short_features_detected = {'lags': [1,3,6,12,24], 'window_sizes': [3,6], 'anomaly_detection_enabled': True}
X_train_, Y_train_, X_test_, Y_test_=preprocess_data(train_dataset, test_dataset, 'CO(GT)', short_features_detected)
# Out:
# C:\LocalFile\9417 Project\.venv\Lib\site-packages\sklearn\pipeline.py:61: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# C:\LocalFile\9417 Project\model_pipeline.py:50: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return X[mask], Y[mask]

# %%
X_train_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4589 entries, 2004-03-11 18:00:00 to 2004-12-27 00:00:00
# Data columns (total 70 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PT08.S1(CO)          4589 non-null   float64
#  1   PT08.S2(NMHC)        4589 non-null   float64
#  2   PT08.S3(NOx)         4589 non-null   float64
#  3   PT08.S4(NO2)         4589 non-null   float64
#  4   PT08.S5(O3)          4589 non-null   float64
#  5   T                    4589 non-null   float64
#  6   RH                   4589 non-null   float64
#  7   AH                   4589 non-null   float64
#  8   PT08.S1(CO)_lag1     4589 non-null   float64
#  9   PT08.S1(CO)_lag3     4589 non-null   float64
#  10  PT08.S1(CO)_lag6     4589 non-null   float64
#  11  PT08.S1(CO)_lag12    4589 non-null   float64
#  12  PT08.S1(CO)_lag24    4589 non-null   float64
#  13  PT08.S2(NMHC)_lag1   4589 non-null   float64
# ...

# %%
print(X_test.shape)
print(X_test_.shape)
# Out:
# (1883, 70)
# (1883, 70)
